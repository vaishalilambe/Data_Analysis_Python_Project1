# %% [markdown]
# ################################################################################################################################
# #                Assignment1: Author-Vaishali Lambe, NUID-001286444                       #
# ################################################################################################################################
# **Question 5:**
#
# * Use Gutenberg and Web_text data. Find out what are the top 5 words that Shakespeare used but we do not use in currently.
# * Take top 50 words from Shakespeare (all 3 books) and top 50 from Web_text (all the records).
# * Remove punctuation and stop words.
# * Remove the words we still use today, and get the unused list. Show the top 5 elements.
#
# ################################################################################################################################

# %%
# Import nltk
import nltk

# Import gutenberg from nltk.corpus
from nltk.corpus import gutenberg

# Import wex_text from nltk.corpus
from nltk.corpus import webtext

# %%
# List of all files from gutenberg
gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
# Import stopwords from nltk.corpus
from nltk.corpus import stopwords

# Get just the Shakespeare files from the Gutenberg collection
shakespeare_files = set([f for f in gutenberg.fileids() if f.startswith('shakespeare')])
# Display all shakespeare flies
print(shakespeare_files)

shakespeare_words= nltk.corpus.gutenberg.words(shakespeare_files)

# Display all shakespeare words
print(shakespeare_words)
# Out:
# {'shakespeare-hamlet.txt', 'shakespeare-macbeth.txt', 'shakespeare-caesar.txt'}
# ['[', 'The', 'Tragedie', 'of', 'Hamlet', 'by', ...]

# %%
# Only consider words that consist entirely of letters, i.e. remove punctuation
# Lowercase them as we go.
shakespeare_letter_words = [w.lower() for w in shakespeare_words if w.isalpha()]
print(shakespeare_letter_words[0:200])
# Out:
# ['the', 'tragedie', 'of', 'hamlet', 'by', 'william', 'shakespeare', 'actus', 'primus', 'scoena', 'prima', 'enter', 'barnardo', 'and', 'francisco', 'two', 'centinels', 'barnardo', 'who', 's', 'there', 'fran', 'nay', 'answer', 'me', 'stand', 'vnfold', 'your', 'selfe', 'bar', 'long', 'liue', 'the', 'king', 'fran', 'barnardo', 'bar', 'he', 'fran', 'you', 'come', 'most', 'carefully', 'vpon', 'your', 'houre', 'bar', 'tis', 'now', 'strook', 'twelue', 'get', 'thee', 'to', 'bed', 'francisco', 'fran', 'for', 'this', 'releefe', 'much', 'thankes', 'tis', 'bitter', 'cold', 'and', 'i', 'am', 'sicke', 'at', 'heart', 'barn', 'haue', 'you', 'had', 'quiet', 'guard', 'fran', 'not', 'a', 'mouse', 'stirring', 'barn', 'well', 'goodnight', 'if', 'you', 'do', 'meet', 'horatio', 'and', 'marcellus', 'the', 'riuals', 'of', 'my', 'watch', 'bid', 'them', 'make', 'hast', 'enter', 'horatio', 'and', 'marcellus', 'fran', 'i', 'thinke', 'i', 'heare', 'them', 'stand', 'who', 's', 'there', 'hor', 'friends', 'to', 'this
# ...

# %%
# Import stopwords from nltk.corpus
from nltk.corpus import stopwords

# Get the English stop words file
stopwords_files = set(["english"])

# We leave the stopwords alone here
stopwords_all_words = stopwords.words(stopwords_files)
print(stopwords_all_words)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'her', 'hers', 'herself', 'it', 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', 'should', '
# ...

# %%
# Create a function, since we'll need to reuse it for the modern words
def get_words(word_list):
    result = {}
    for w in word_list:
        # Remove "words" that are caused by splitting contractions.
        if not w in stopwords_all_words: #list(['d','m','s','t','th']):
            if w in result:
                result[w] = result[w] + 1
            else:
                result[w] = 1
    return result

# Pass Shakespeare letter words to get_words() function to get shakespeare updated word list
shakespeare_word_updated = get_words(shakespeare_letter_words)

# Display all shapespeare words without punctuationa and stopwrods
print("\nRemoving stopwords and punctuation the total words in shakespeare are: ", len(shakespeare_word_updated))
print("========================================================================================================================")
print(shakespeare_word_updated)
# Out:
# Removing stopwords and punctuation the total words in shakespeare are:  7429
# ...

# %% [markdown]
# **Answer**

# %%
# Sort the words by their frequency, descending
# Another function so it can be reused
def sort_word_counts(word_counts):
    sorted_words = sorted(word_counts, key=lambda item : word_counts[item], reverse=True)
    
    result = []
    for w in sorted_words:
        result.append({'word':w, 'count':word_counts[w]})

    return result

sorted_shakespeare_list = sort_word_counts(shakespeare_word_updated)
shakespeare_top50_words = sorted_shakespeare_list[0:50]

shakespeare_top50_words_list = [item["word"] for item in shakespeare_top50_words]

# Display top 50 shakespeare words
print("\nTop 50 Shakespeare words are:")
print("========================================================================================================================")
print(shakespeare_top50_words_list)
# Out:
# Top 50 Shakespeare words are:
# ...
# ['haue', 'ham', 'thou', 'shall', 'lord', 'come', 'king', 'enter', 'good', 'let', 'thy', 'caesar', 'vs', 'know', 'thee', 'would', 'like', 'vpon', 'brutus', 'bru', 'well', 'hath', 'selfe', 'man', 'may', 'macb', 'yet', 'heere', 'say', 'must', 'tis', 'th', 'make', 'speake', 'loue', 'giue', 'see', 'time', 'night', 'sir', 'one', 'st', 'cassi', 'ile', 'doe', 'hamlet', 'go', 'men', 'hor', 'vp']

# %%
# Display webtext files
webtext.fileids()
# Out:
# ['firefox.txt',
#  'grail.txt',
#  'overheard.txt',
#  'pirates.txt',
#  'singles.txt',
#  'wine.txt']

# %%
# Get all files from the webtext collection
webtext_files = set([f for f in webtext.fileids()])
webtext_files
# Out:
# {'firefox.txt',
#  'grail.txt',
#  'overheard.txt',
#  'pirates.txt',
#  'singles.txt',
#  'wine.txt'}

# %%
# Read all words
webtext_all_words = webtext.words(webtext_files)

# %%
# Only consider words that consist entirely of letters, i.e. remove punctuation
# Lowercase them as we go

webtext_letter_words = [w.lower() for w in webtext_all_words if w.isalpha()]
print(webtext_letter_words[0:200])
# Out:
# ['scene', 'wind', 'clop', 'clop', 'clop', 'king', 'arthur', 'whoa', 'there', 'clop', 'clop', 'clop', 'soldier', 'halt', 'who', 'goes', 'there', 'arthur', 'it', 'is', 'i', 'arthur', 'son', 'of', 'uther', 'pendragon', 'from', 'the', 'castle', 'of', 'camelot', 'king', 'of', 'the', 'britons', 'defeator', 'of', 'the', 'saxons', 'sovereign', 'of', 'all', 'england', 'soldier', 'pull', 'the', 'other', 'one', 'arthur', 'i', 'am', 'and', 'this', 'is', 'my', 'trusty', 'servant', 'patsy', 'we', 'have', 'ridden', 'the', 'length', 'and', 'breadth', 'of', 'the', 'land', 'in', 'search', 'of', 'knights', 'who', 'will', 'join', 'me', 'in', 'my', 'court', 'at', 'camelot', 'i', 'must', 'speak', 'with', 'your', 'lord', 'and', 'master', 'soldier', 'what', 'ridden', 'on', 'a', 'horse', 'arthur', 'yes', 'soldier', 'you', 're', 'using', 'coconuts', 'arthur', 'what', 'soldier', 'you', 've', 'got', 'two', 'empty', 'halves', 'of', 'coconut', 'and', 'you', 're', 'bangin', 'em', 'together', 'arthur', 'so', 'we', 
# ...

# %%
# Pass webtext words to function get_words()
webtext_word_updated = get_words(webtext_letter_words)

print("\nRemoving stopwords and punctuation the total words in webtext are: ", len(webtext_word_updated))
print("========================================================================================================================")
print(webtext_word_updated)
# Out:
# Removing stopwords and punctuation the total words in webtext are:  16303
# ...

# %% [markdown]
# **Answer**

# %%
# Sort the webtext words and get it into list
sorted_webtext_list = sort_word_counts(webtext_word_updated)
webtext_top50_words = sorted_webtext_list[0:50]

# Display top 50 webtext words
print("\nTop 50 webtext words are:")
print("========================================================================================================================")
print(webtext_top50_words[0:50])
# Out:
# Top 50 webtext words are:
# ...

# %% [markdown]
# **Answer**

# %%
webtext_top50_words_list = [item["word"] for item in webtext_top50_words]

# Display top 50 modern words
print("\nTop 50 modern words:")
print("=========================================================================================================================")
print(webtext_top50_words_list)
# Out:
# Top 50 modern words:
# ...
# ['girl', 'guy', 'like', 'man', 'know', 'woman', 'yeah', 'page', 'firefox', 'get', 'new', 'chick', 'one', 'oh', 'open', 'window', 'good', 'bookmarks', 'teen', 'well', 'firebird', 'cell', 'right', 'go', 'work', 'bar', 'menu', 'tab', 'lady', 'toolbar', 'boy', 'want', 'think', 'browser', 'jack', 'bookmark', 'old', 'really', 'going', 'download', 'url', 'back', 'time', 'black', 'manager', 'little', 'got', 'crash', 'would', 'button']

# %% [markdown]
# **Answer**

# %%
# Create a list which contains shakespeare words which are t present in modern words i.e. webtext
obsolete_words_list = []
for item in shakespeare_top50_words_list:
    if not item in sorted_webtext_list:
        obsolete_words_list.append(item)

# Display all top 50 Shakespeare words not in top modern words
print("\nAll top 50 Shakespeare words that are NOT in the modern words:")
print("========================================================================================================================")
print(obsolete_words_list)

# Display all top 5 Shakespeare words not in top modern words
print("\nTop 5 Shakespeare words that are NOT in the modern words:")
print("========================================================================================================================")
print(obsolete_words_list[0:5])
# Out:
# All top 50 Shakespeare words that are NOT in the modern words:
# ...
# ['haue', 'ham', 'thou', 'shall', 'lord', 'come', 'king', 'enter', 'good', 'let', 'thy', 'caesar', 'vs', 'know', 'thee', 'would', 'like', 'vpon', 'brutus', 'bru', 'well', 'hath', 'selfe', 'man', 'may', 'macb', 'yet', 'heere', 'say', 'must', 'tis', 'th', 'make', 'speake', 'loue', 'giue', 'see', 'time', 'night', 'sir', 'one', 'st', 'cassi', 'ile', 'doe', 'hamlet', 'go', 'men', 'hor', 'vp']
#
# Top 5 Shakespeare words that are NOT in the modern words:
# ...
# ['haue', 'ham', 'thou', 'shall', 'lord']
